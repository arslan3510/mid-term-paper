# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv("data1.csv")
df
plt.xlabel("cake")
plt.ylabel("price")
plt.scatter(df.cake,df.price)
plt
reg = LinearRegression()
reg.fit(df[["cake"]],df.price)
reg.predict([[12]])
# Out:
# c:\Users\Fahad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1431.51515152])
